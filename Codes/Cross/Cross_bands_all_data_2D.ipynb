# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from scipy.signal import butter, filtfilt, lfilter
import matplotlib.pyplot as plt
import gc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Flatten, Dropout
from tensorflow.keras.layers import TimeDistributed, Reshape, Permute
from keras.utils import to_categorical
from tensorflow import keras
import pywt
import scipy.signal as signal
from scipy.integrate import simps

import scipy

# %%
# ---------- FUNCTIONS ---------- #

#___SCALING___#
def apply_scaling(array):
  array_norm = np.zeros((array.shape[0],array.shape[1]))
  for i in range(array.shape[0]):
    means = np.mean(array[i])  # Calculate mean for each sensor
    stds = np.std(array[i])    # Calculate standard deviation for each sensor
    array_norm[i] = (array[i] - means) / stds   # Subtrack and divide

  del array, means, stds
  gc.collect()
  return array_norm

#___LOWPASS FILTER___#
def butter_lowpass_filter(data, cutoff, fs, order=5):
    nyq = 0.5 * fs  # Nyquist Frequency
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

def apply_lowpass(array):
  original_sampling_rate = 2034  # Original sampling rate
  downsampling_factor = 4
  new_sampling_rate = original_sampling_rate / downsampling_factor  # New sampling rate after downsampling
  cutoff_frequency = new_sampling_rate / 2  # Nyquist frequency

  array_filtered = np.zeros((array.shape[0], array.shape[1]))

  for i in range(array.shape[0]):  # Iterate over sensors
      array_filtered[i, :] = butter_lowpass_filter(array[i, :], cutoff_frequency, original_sampling_rate)

  del array
  return array_filtered

#___DOWNSAMPLING___#
def apply_downsampling(array):
  n_sensors, n_timepoints = array.shape

  downsampling_factor = 4
  new_n_timepoints = n_timepoints // downsampling_factor
  array_downsamp = np.zeros((n_sensors, new_n_timepoints))

  for sensor in range(n_sensors):
    array_downsamp[sensor,:] = array[sensor, ::downsampling_factor]

  del array, new_n_timepoints, downsampling_factor, n_sensors, n_timepoints
  gc.collect()
  return array_downsamp


#___BANDS AND STATS___#
def bandpass_filter(data, lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = scipy.signal.butter(order, [low, high], btype='band')
    y = scipy.signal.filtfilt(b, a, data)
    return y


def bandpass_filter(data, lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = scipy.signal.butter(order, [low, high], btype='band')
    y = scipy.signal.filtfilt(b, a, data)
    return y

def extract_frequency_bands(data, fs):
    # Define the frequency bands
    bands = {'delta': (0.5, 4), 'theta': (4, 8), 'alpha': (8, 12), 'beta': (12, 30), 'gamma': (30, 80)}

    # Initialize the output
    extracted_features = np.zeros((data.shape[0], 25))  # 248 sensors, 5 bands * 5 features

    for sensor_index in range(data.shape[0]):
        sensor_data = data[sensor_index, :]

        features = []
        for band in bands.values():
            # Apply bandpass filter
            band_data = bandpass_filter(sensor_data, band[0], band[1], fs=fs)

            # Calculate statistical features
            features.append(np.mean(band_data))
            features.append(np.std(band_data))
            features.append(scipy.stats.skew(band_data))
            features.append(scipy.stats.kurtosis(band_data))
            features.append(np.sum(np.square(band_data)))  # Energy

        extracted_features[sensor_index, :] = features

    return extracted_features

# %%
# LOAD FILES

def get_file_paths_and_labels(data_folder, task_numbers):
  file_paths = []
  labels = []
  for task_number in task_numbers:
      for file in os.listdir(data_folder):
          if file.endswith(task_number + 'h5'):
              file_path = os.path.join(data_folder, file)
              file_paths.append(file_path)
              labels.append(assign_label(file))
  return file_paths, labels

def find_fmri_data_folder(start_path):
    for root, dirs, files in os.walk(start_path):
        if 'meg_data' in dirs:
            return os.path.join(root, 'meg_data/Cross/train')
    raise Exception("meg_data folder not found. Please check the directory structure.")

def load_data(file_path):
  with h5py.File(file_path, 'r') as f:
      dataset_name = get_dataset_name(file_path)
      matrix = f.get(dataset_name)[:]
      return matrix

def get_dataset_name(file_name_with_dir):
  filename_without_dir = file_name_with_dir.split('/')[-1]
  temp = filename_without_dir.split('_')[:-1]
  dataset_name = "_".join(temp)
  return dataset_name

def assign_label(file_name):
  if file_name.startswith("rest"):
      return 0
  elif file_name.startswith("task_motor"):
      return 1
  elif file_name.startswith("task_story"):
      return 2
  elif file_name.startswith("task_working"):
      return 3
  else:
      return None

def count_files_with_task_numbers(data_folder, task_numbers):
    total_files = 0
    for file in os.listdir(data_folder):
        if any(file.endswith(task_number + 'h5') for task_number in task_numbers):
            total_files += 1
    return total_files

# %%
# ----- MODEL ----- #

def build_ffnn_model(input_shape, num_classes):
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))  # Flatten the input
    model.add(Dense(64, activation='relu'))  # First hidden layer
    # model.add(Dropout(0.5))  # Dropout layer for regularization
    model.add(Dense(128, activation='relu'))  # Second hidden layer
    # model.add(Dropout(0.5))  # Another dropout layer
    model.add(Dense(num_classes, activation='softmax'))  # Output layer

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
############################################################################
# ------------------------------ Train Data ------------------------------ #
############################################################################

# %%
# Call Preprocessing functions
def preprocess_data(data, i):
  print(f"*** FILE {i} ***")
  data = data[:, :-8]
  data = apply_scaling(data)
  print("scaling applied: shape:", data.shape, end=', ')
  data = apply_lowpass(data)
  print("lowpass applied: shape:", data.shape, end=', ')
  data = apply_downsampling(data)
  print("downsam applied: shape:", data.shape, end=', ')
  bands_data = extract_frequency_bands(data, 2034/12)
  print("Data after extracting features:", np.array(bands_data).shape)
  del data
  return np.array(bands_data)

# %%
# Retieve the initial data from the folder

fmri_data_folder = find_fmri_data_folder('/content/drive')
print("fmri_data_folder:", fmri_data_folder)

meg_data_list = []
labels = []

for file in os.listdir(fmri_data_folder):
    if file.endswith('.h5'):
        file_path = os.path.join(fmri_data_folder, file)
        data = load_data(file_path)
        meg_data_list.append(data)
        labels.append(assign_label(file))

        # Clear memory
        del data
        gc.collect()

# Convert the list of 2D arrays into a single 3D NumPy array
meg_train_data_array = np.stack(meg_data_list, axis=0)
labels_train_array = np.array(labels)

del meg_data_list
# Out:
# fmri_data_folder: /content/drive/MyDrive/Courses/Pattern Recognition/Lab/Group Assignment/meg_data/Cross/train

# %%
print("## Initial shapes of the data ##")
print("MEG:", meg_train_data_array.shape)
print("Labels:",labels_train_array.shape)
# Out:
# ## Initial shapes of the data ##
# MEG: (64, 248, 35624)
# Labels: (64,)

# %%
# ----- CALL PROCESSING FUNCTIONS FOR ALL FILES ----- #

processed_data = np.zeros((meg_train_data_array.shape[0], meg_train_data_array.shape[1], 25))
print(processed_data.shape)
for i in range(meg_train_data_array.shape[0]):
  processed_data[i] = preprocess_data(meg_train_data_array[i], i+1)
# Out:
# (64, 248, 25)
# *** FILE 1 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 2 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 3 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 4 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 5 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 6 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 7 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 8 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 9 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 10 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 11 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 12 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 13 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 14 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 15 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 16 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 17 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 18 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 19 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 20 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 21 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 22 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 23 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 24 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 25 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 26 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 27 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 28 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 29 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 30 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 31 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 32 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 33 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 34 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 35 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 36 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 37 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 38 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 39 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 40 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 41 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 42 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 43 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 44 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 45 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 46 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 47 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 48 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 49 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 50 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 51 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 52 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 53 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 54 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 55 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 56 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 57 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 58 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 59 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 60 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 61 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 62 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 63 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 64 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)

# %%
X_train = processed_data
y_train = to_categorical(labels_train_array, num_classes=4)

del processed_data, labels_train_array

# %%
print("## Final shapes of the data ##")
print("MEG:", X_train.shape)
print("Labels:",y_train.shape)
# Out:
# ## Final shapes of the data ##
# MEG: (64, 248, 25)
# Labels: (64, 4)

# %%
# ----- TRAINING THE MODEL ----- #

model = build_ffnn_model(input_shape=(248, 25), num_classes=4)

history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 22ms/step - loss: 422.4425 - accuracy: 0.2656
# Epoch 2/50
# 2/2 [==============================] - 0s 16ms/step - loss: 465.8124 - accuracy: 0.2969
# Epoch 3/50
# 2/2 [==============================] - 0s 14ms/step - loss: 188.7888 - accuracy: 0.3125
# Epoch 4/50
# 2/2 [==============================] - 0s 16ms/step - loss: 234.9014 - accuracy: 0.1719
# Epoch 5/50
# 2/2 [==============================] - 0s 17ms/step - loss: 136.0300 - accuracy: 0.3906
# Epoch 6/50
# 2/2 [==============================] - 0s 13ms/step - loss: 143.5844 - accuracy: 0.5156
# Epoch 7/50
# 2/2 [==============================] - 0s 16ms/step - loss: 145.7512 - accuracy: 0.5312
# Epoch 8/50
# 2/2 [==============================] - 0s 17ms/step - loss: 65.4060 - accuracy: 0.6875
# Epoch 9/50
# 2/2 [==============================] - 0s 17ms/step - loss: 52.8665 - accuracy: 0.4688
# Epoch 10/50
# 2/2 [==============================] - 0s 15ms/step - loss: 36.9393 - accuracy: 0.5469
# Epoch 11/50
# 2/2 [==============================] - 0s 19ms/step - loss: 39.5035 - accuracy: 0.8594
# Epoch 12/50
# 2/2 [==============================] - 0s 17ms/step - loss: 51.0385 - accuracy: 0.7344
# Epoch 13/50
# 2/2 [==============================] - 0s 15ms/step - loss: 19.0565 - accuracy: 0.7812
# Epoch 14/50
# 2/2 [==============================] - 0s 16ms/step - loss: 19.2540 - accuracy: 0.7500
# Epoch 15/50
# 2/2 [==============================] - 0s 16ms/step - loss: 22.8778 - accuracy: 0.6562
# Epoch 16/50
# 2/2 [==============================] - 0s 16ms/step - loss: 11.8369 - accuracy: 0.7812
# Epoch 17/50
# 2/2 [==============================] - 0s 18ms/step - loss: 6.9214 - accuracy: 0.7969
# Epoch 18/50
# 2/2 [==============================] - 0s 16ms/step - loss: 9.0265 - accuracy: 0.8281
# Epoch 19/50
# 2/2 [==============================] - 0s 16ms/step - loss: 12.2916 - accuracy: 0.7969
# Epoch 20/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.9922 - accuracy: 0.9531
# Epoch 21/50
# 2/2 [==============================] - 0s 15ms/step - loss: 4.4248 - accuracy: 0.8438
# Epoch 22/50
# 2/2 [==============================] - 0s 19ms/step - loss: 6.3297 - accuracy: 0.8750
# Epoch 23/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3328 - accuracy: 0.9688
# Epoch 24/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3660 - accuracy: 0.9688
# Epoch 25/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8646 - accuracy: 0.9375
# Epoch 26/50
# 2/2 [==============================] - 0s 18ms/step - loss: 3.3290 - accuracy: 0.9375
# Epoch 27/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2537 - accuracy: 0.9844
# Epoch 28/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3290 - accuracy: 0.9844
# Epoch 29/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2441 - accuracy: 0.9844
# Epoch 30/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3080 - accuracy: 0.9844
# Epoch 33/50
# 2/2 [==============================] - 0s 16ms/step - loss: 6.1719e-04 - accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1767 - accuracy: 0.9844
# Epoch 35/50
# 2/2 [==============================] - 0s 15ms/step - loss: 1.3670e-04 - accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0600e-04 - accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 0s 14ms/step - loss: 5.9215e-05 - accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0132 - accuracy: 0.9844
# Epoch 40/50
# 2/2 [==============================] - 0s 15ms/step - loss: 2.2717e-05 - accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2783e-05 - accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8504e-04 - accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0193 - accuracy: 0.9844
# Epoch 44/50
# 2/2 [==============================] - 0s 14ms/step - loss: 9.3537e-06 - accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0080e-05 - accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 0s 14ms/step - loss: 2.0314e-04 - accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 0s 14ms/step - loss: 9.7335e-06 - accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 0s 14ms/step - loss: 9.2085e-06 - accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 0s 14ms/step - loss: 8.7934e-06 - accuracy: 1.0000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# Plot training accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

# Plot training loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.show()

# %%
del X_train, y_train

# %%
############################################################################
# ------------------------------ Test Data ------------------------------ #
############################################################################

# %%
# ----- RETRIEVE TEST DATA 1 ----- #

def find_fmri_data_folder(start_path):
    for root, dirs, files in os.walk(start_path):
        if 'meg_data' in dirs:
            return os.path.join(root, 'meg_data/Cross/test1')
    raise Exception("meg_data folder not found. Please check the directory structure.")

def get_dataset_name(file_name_with_dir):
    filename_without_dir = file_name_with_dir.split('/')[-1]
    temp = filename_without_dir.split('_')[:-1]
    dataset_name = "_".join(temp)
    return dataset_name

def assign_label(file_name):
    if file_name.startswith("rest"):
        return 0
    elif file_name.startswith("task_motor"):
        return 1
    elif file_name.startswith("task_story"):
        return 2
    elif file_name.startswith("task_working"):
        return 3
    else:
        return None

def load_data(file_path):
    with h5py.File(file_path, 'r') as f:
        dataset_name = get_dataset_name(file_path)
        matrix = f.get(dataset_name)[:]
        return matrix

fmri_data_folder = find_fmri_data_folder('/content/drive')
meg_test_data_list = []
labels_test = []

for file in os.listdir(fmri_data_folder):
    if file.endswith('.h5'):
        file_path = os.path.join(fmri_data_folder, file)
        data = load_data(file_path)
        meg_test_data_list.append(data)
        labels_test.append(assign_label(file))

        # Clear memory
        del data
        gc.collect()

# Convert the list of 2D arrays into a single 3D NumPy array
meg_test_data_array = np.stack(meg_test_data_list, axis=0)
labels_test_array = np.array(labels_test)

print("## Initial shapes of the test data ##")
print(meg_test_data_array.shape)
print(labels_test_array.shape)

del meg_test_data_list, labels_test
# Out:
# ## Initial shapes of the test data ##
# (16, 248, 35624)
# (16,)

# %%
# ----- CALLING THE PROCESSING FUNCTION ----- #

processed_data = np.zeros((meg_test_data_array.shape[0], meg_test_data_array.shape[1], 25))
print(processed_data.shape)
for i in range(meg_test_data_array.shape[0]):
  processed_data[i] = preprocess_data(meg_test_data_array[i], i+1)
# Out:
# (16, 248, 25)
# *** FILE 1 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 2 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 3 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 4 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 5 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 6 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 7 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 8 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 9 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 10 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 11 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 12 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 13 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 14 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 15 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 16 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)

# %%
X_test = processed_data
y_test = to_categorical(labels_test_array, num_classes=4)

del processed_data, labels_test_array

# %%
print("## Data after processing ##")
print("MEG:", X_test.shape)
print("Labels:", y_test.shape)
# Out:
# ## Data after processing ##
# MEG: (16, 248, 25)
# Labels: (16, 4)

# %%
# TEST EACH SENSOR INDEPENDENTLY

test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 451ms/step - loss: 48.6779 - accuracy: 0.5625

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)

# Convert predictions and true labels to single labels if they are one-hot encoded
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
# Out:
# 1/1 [==============================] - 0s 113ms/step

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.show()

# %%
# ----- RETRIEVE TEST DATA 2 ----- #

def find_fmri_data_folder(start_path):
    for root, dirs, files in os.walk(start_path):
        if 'meg_data' in dirs:
            return os.path.join(root, 'meg_data/Cross/test2')
    raise Exception("meg_data folder not found. Please check the directory structure.")

def get_dataset_name(file_name_with_dir):
    filename_without_dir = file_name_with_dir.split('/')[-1]
    temp = filename_without_dir.split('_')[:-1]
    dataset_name = "_".join(temp)
    return dataset_name

def assign_label(file_name):
    if file_name.startswith("rest"):
        return 0
    elif file_name.startswith("task_motor"):
        return 1
    elif file_name.startswith("task_story"):
        return 2
    elif file_name.startswith("task_working"):
        return 3
    else:
        return None

def load_data(file_path):
    with h5py.File(file_path, 'r') as f:
        dataset_name = get_dataset_name(file_path)
        matrix = f.get(dataset_name)[:]
        return matrix

fmri_data_folder = find_fmri_data_folder('/content/drive')
meg_test_data_list = []
labels_test = []

for file in os.listdir(fmri_data_folder):
    if file.endswith('.h5'):
        file_path = os.path.join(fmri_data_folder, file)
        data = load_data(file_path)
        meg_test_data_list.append(data)
        labels_test.append(assign_label(file))

        # Clear memory
        del data
        gc.collect()

# Convert the list of 2D arrays into a single 3D NumPy array
meg_test_data_array = np.stack(meg_test_data_list, axis=0)
labels_test_array = np.array(labels_test)

print("## Initial shapes of the test data ##")
print(meg_test_data_array.shape)
print(labels_test_array.shape)

del meg_test_data_list, labels_test
# Out:
# ## Initial shapes of the test data ##
# (16, 248, 35624)
# (16,)

# %%
# ----- CALLING THE PROCESSING FUNCTION ----- #

processed_data = np.zeros((meg_test_data_array.shape[0], meg_test_data_array.shape[1], 25))
print(processed_data.shape)
for i in range(meg_test_data_array.shape[0]):
  processed_data[i] = preprocess_data(meg_test_data_array[i], i+1)
# Out:
# (16, 248, 25)
# *** FILE 1 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 2 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 3 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 4 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 5 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 6 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 7 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 8 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 9 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 10 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 11 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 12 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 13 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 14 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 15 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 16 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)

# %%
X_test = processed_data
y_test = to_categorical(labels_test_array, num_classes=4)

del processed_data, labels_test_array

# %%
print("## Data after processing ##")
print("MEG:", X_test.shape)
print("Labels:", y_test.shape)
# Out:
# ## Data after processing ##
# MEG: (16, 248, 25)
# Labels: (16, 4)

# %%
# TEST EACH SENSOR INDEPENDENTLY

test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 33ms/step - loss: 60.1706 - accuracy: 0.2500

# %%
y_pred = model.predict(X_test)

# Convert predictions and true labels to single labels if they are one-hot encoded
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.show()

# %%
# ----- RETRIEVE TEST DATA 2 ----- #

def find_fmri_data_folder(start_path):
    for root, dirs, files in os.walk(start_path):
        if 'meg_data' in dirs:
            return os.path.join(root, 'meg_data/Cross/test3')
    raise Exception("meg_data folder not found. Please check the directory structure.")

def get_dataset_name(file_name_with_dir):
    filename_without_dir = file_name_with_dir.split('/')[-1]
    temp = filename_without_dir.split('_')[:-1]
    dataset_name = "_".join(temp)
    return dataset_name

def assign_label(file_name):
    if file_name.startswith("rest"):
        return 0
    elif file_name.startswith("task_motor"):
        return 1
    elif file_name.startswith("task_story"):
        return 2
    elif file_name.startswith("task_working"):
        return 3
    else:
        return None

def load_data(file_path):
    with h5py.File(file_path, 'r') as f:
        dataset_name = get_dataset_name(file_path)
        matrix = f.get(dataset_name)[:]
        return matrix

fmri_data_folder = find_fmri_data_folder('/content/drive')
meg_test_data_list = []
labels_test = []

for file in os.listdir(fmri_data_folder):
    if file.endswith('.h5'):
        file_path = os.path.join(fmri_data_folder, file)
        data = load_data(file_path)
        meg_test_data_list.append(data)
        labels_test.append(assign_label(file))

        # Clear memory
        del data
        gc.collect()

# Convert the list of 2D arrays into a single 3D NumPy array
meg_test_data_array = np.stack(meg_test_data_list, axis=0)
labels_test_array = np.array(labels_test)

print("## Initial shapes of the test data ##")
print(meg_test_data_array.shape)
print(labels_test_array.shape)

del meg_test_data_list, labels_test
# Out:
# ## Initial shapes of the test data ##
# (16, 248, 35624)
# (16,)

# %%
# ----- CALLING THE PROCESSING FUNCTION ----- #

processed_data = np.zeros((meg_test_data_array.shape[0], meg_test_data_array.shape[1], 25))
print(processed_data.shape)
for i in range(meg_test_data_array.shape[0]):
  processed_data[i] = preprocess_data(meg_test_data_array[i], i+1)
# Out:
# (16, 248, 25)
# *** FILE 1 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 2 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 3 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 4 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 5 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 6 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 7 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 8 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 9 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 10 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 11 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 12 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 13 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 14 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 15 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)
# *** FILE 16 ***
# scaling applied: shape: (248, 35616), lowpass applied: shape: (248, 35616), downsam applied: shape: (248, 8904), Data after extracting features: (248, 25)

# %%
X_test = processed_data
y_test = to_categorical(labels_test_array, num_classes=4)

del processed_data, labels_test_array

# %%
print("## Data after processing ##")
print("MEG:", X_test.shape)
print("Labels:", y_test.shape)
# Out:
# ## Data after processing ##
# MEG: (16, 248, 25)
# Labels: (16, 4)

# %%
# TEST EACH SENSOR INDEPENDENTLY

test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 60ms/step - loss: 34.2512 - accuracy: 0.5625

# %%
y_pred = model.predict(X_test)

# Convert predictions and true labels to single labels if they are one-hot encoded
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
# Out:
# 1/1 [==============================] - 0s 40ms/step

# %%
# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.show()
